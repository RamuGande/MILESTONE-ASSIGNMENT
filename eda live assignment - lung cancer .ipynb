# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"C:\Users\hp\Desktop\GEN AI - PRACTICE\Projects\lungs_cancer\dataset.csv")

# %%
df
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         M   65        1               1        1              2
# 1         F   55        1               2        2              1
# 2         F   78        2               2        1              1
# 3         M   60        2               1        1              1
# 4         F   80        1               1        2              1
# ...     ...  ...      ...             ...      ...            ...
# 2995      F   71        2               1        1              2
# 2996      F   75        1               2        1              1
# 2997      F   62        2               2        2              1
# 2998      M   30        1               1        2              2
# 2999      M   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0                   2        1        2         2                  2
# ...

# %%
df.describe()
# Out:
#                AGE      SMOKING  YELLOW_FINGERS      ANXIETY  PEER_PRESSURE  \
# count  3000.000000  3000.000000     3000.000000  3000.000000    3000.000000
# mean     55.169000     1.491000        1.514000     1.494000       1.499000
# std      14.723746     0.500002        0.499887     0.500047       0.500082
# min      30.000000     1.000000        1.000000     1.000000       1.000000
# 25%      42.000000     1.000000        1.000000     1.000000       1.000000
# 50%      55.000000     1.000000        2.000000     1.000000       1.000000
# 75%      68.000000     2.000000        2.000000     2.000000       2.000000
# max      80.000000     2.000000        2.000000     2.000000       2.000000
#
#        CHRONIC_DISEASE      FATIGUE      ALLERGY     WHEEZING  \
# count      3000.000000  3000.000000  3000.000000  3000.000000
# mean          1.509667     1.489667     1.506667     1.497333
# std           0.499990     0.499977     0.500039     0.500076
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 3000 non-null   object
#  1   AGE                    3000 non-null   int64
#  2   SMOKING                3000 non-null   int64
#  3   YELLOW_FINGERS         3000 non-null   int64
#  4   ANXIETY                3000 non-null   int64
#  5   PEER_PRESSURE          3000 non-null   int64
#  6   CHRONIC_DISEASE        3000 non-null   int64
#  7   FATIGUE                3000 non-null   int64
#  8   ALLERGY                3000 non-null   int64
#  9   WHEEZING               3000 non-null   int64
#  10  ALCOHOL_CONSUMING      3000 non-null   int64
#  11  COUGHING               3000 non-null   int64
#  12  SHORTNESS_OF_BREATH    3000 non-null   int64
#  13  SWALLOWING_DIFFICULTY  3000 non-null   int64
#  14  CHEST_PAIN             3000 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC_DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
#        'ALCOHOL_CONSUMING', 'COUGHING', 'SHORTNESS_OF_BREATH',
#        'SWALLOWING_DIFFICULTY', 'CHEST_PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC_DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL_CONSUMING        0
# COUGHING                 0
# SHORTNESS_OF_BREATH      0
# SWALLOWING_DIFFICULTY    0
# CHEST_PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         M   65        1               1        1              2
# 1         F   55        1               2        2              1
# 2         F   78        2               2        1              1
# 3         M   60        2               1        1              1
# 4         F   80        1               1        2              1
# ...     ...  ...      ...             ...      ...            ...
# 2995      F   71        2               1        1              2
# 2996      F   75        1               2        1              1
# 2997      F   62        2               2        2              1
# 2998      M   30        1               1        2              2
# 2999      M   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0                   2        1        2         2                  2
# ...

# %%
for col in df.columns:
    print(f"{col} unique values {df[col].unique()}\n")
# Out:
# GENDER unique values ['M' 'F']
#
# AGE unique values [65 55 78 60 80 58 70 74 77 67 35 79 39 62 64 66 76 48 33 47 50 36 37 51
#  53 72 71 54 41 46 59 32 34 44 38 69 45 40 63 75 52 31 57 73 42 56 68 61
#  30 49 43]
#
# SMOKING unique values [1 2]
#
# YELLOW_FINGERS unique values [1 2]
#
# ANXIETY unique values [1 2]
#
# PEER_PRESSURE unique values [2 1]
#
# CHRONIC_DISEASE unique values [2 1]
#
# FATIGUE unique values [1 2]
#
# ALLERGY unique values [2 1]
#
# WHEEZING unique values [2 1]
#
# ALCOHOL_CONSUMING unique values [2 1]
#
# COUGHING unique values [2 1]
#
# SHORTNESS_OF_BREATH unique values [2 1]
#
# SWALLOWING_DIFFICULTY unique values [2 1]
#
# CHEST_PAIN unique values [1 2]
#
# LUNG_CANCER unique values ['NO' 'YES']

# %%
cat_cols = [col for col in df.columns if df[col].dtype == 'O']

# %%
cat_cols
# Out:
# ['GENDER', 'LUNG_CANCER']

# %%
df['GENDER']=df['GENDER'].map({'M':'0','F':'1'})

# %%
df['LUNG_CANCER']=df['LUNG_CANCER'].map({'NO':'0','YES':'1'})

# %%
df
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         0   65        1               1        1              2
# 1         1   55        1               2        2              1
# 2         1   78        2               2        1              1
# 3         0   60        2               1        1              1
# 4         1   80        1               1        2              1
# ...     ...  ...      ...             ...      ...            ...
# 2995      1   71        2               1        1              2
# 2996      1   75        1               2        1              1
# 2997      1   62        2               2        2              1
# 2998      0   30        1               1        2              2
# 2999      0   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0                   2        1        2         2                  2
# ...

# %%
df.dtypes
# Out:
# GENDER                   object
# AGE                       int64
# SMOKING                   int64
# YELLOW_FINGERS            int64
# ANXIETY                   int64
# PEER_PRESSURE             int64
# CHRONIC_DISEASE           int64
# FATIGUE                   int64
# ALLERGY                   int64
# WHEEZING                  int64
# ALCOHOL_CONSUMING         int64
# COUGHING                  int64
# SHORTNESS_OF_BREATH       int64
# SWALLOWING_DIFFICULTY     int64
# CHEST_PAIN                int64
# LUNG_CANCER              object
# dtype: object

# %%
plt.figure(figsize=(7,7))
sns.countplot(data=df,x='SHORTNESS_OF_BREATH',hue='LUNG_CANCER')
plt.legend(["Has cancer", 'Does not have cancer'])

# %%
plt.figure(figsize=(6,6))
sns.countplot(data=df,x='ANXIETY',hue='SHORTNESS_OF_BREATH')
plt.legend(["Difficulty Breathing", 'No Difficulty Breathing'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 2
#       1 plt.figure(figsize=(6,6))
# ----> 2 sns.countplot(data=df,x='ANXIETY',hue='SHORTNESS_OF_BREATH')
#       3 plt.legend(["Difficulty Breathing", 'No Difficulty Breathing'])
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# ...

# %%
df['GENDER'] = df['GENDER'].astype('int')

# %%
df['LUNG_CANCER'] = df['LUNG_CANCER'].astype('int')

# %%
df.dtypes
# Out:
# GENDER                   int32
# AGE                      int64
# SMOKING                  int64
# YELLOW_FINGERS           int64
# ANXIETY                  int64
# PEER_PRESSURE            int64
# CHRONIC_DISEASE          int64
# FATIGUE                  int64
# ALLERGY                  int64
# WHEEZING                 int64
# ALCOHOL_CONSUMING        int64
# COUGHING                 int64
# SHORTNESS_OF_BREATH      int64
# SWALLOWING_DIFFICULTY    int64
# CHEST_PAIN               int64
# LUNG_CANCER              int32
# dtype: object

# %%
#visualization

# %%
sns.distplot(x = df['LUNG_CANCER'])
# Out:
# <Axes: ylabel='Density'>

# %%
sns.countplot(x = 'SMOKING',data = df)
# Out:
# <Axes: xlabel='SMOKING', ylabel='count'>

# %%
sns.countplot(x = 'ANXIETY',data = df)
# Out:
# <Axes: xlabel='ANXIETY', ylabel='count'>

# %%
sns.countplot(x = 'PEER_PRESSURE',data = df)
# Out:
# <Axes: xlabel='PEER_PRESSURE', ylabel='count'>

# %%
sns.boxplot(x = df['AGE'])#no any outliers
# Out:
# <Axes: xlabel='AGE'>

# %%
k = df[(df['ALLERGY'] == 1) & (df['LUNG_CANCER'] == 1)]
k#743 people who has ALLERGY AND CANCER
# Out:
#       GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 2          1   78        2               2        1              1
# 12         0   79        1               1        1              2
# 26         0   36        2               1        1              2
# 28         0   51        1               1        2              1
# 29         1   51        2               2        2              1
# ...      ...  ...      ...             ...      ...            ...
# 2974       1   52        2               2        1              1
# 2976       1   52        1               1        1              2
# 2981       0   41        1               1        1              1
# 2983       1   30        1               1        2              2
# 2989       1   74        2               1        2              2
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 2                   1        2        1         2                  1
# ...

# %%
k = df[(df['SMOKING'] == 1) & (df['LUNG_CANCER'] == 1)]
k#761 pople has lung cancer who smokes
# Out:
#       GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 5          1   58        1               1        1              2
# 6          1   70        1               1        1              2
# 12         0   79        1               1        1              2
# 16         0   62        1               1        2              2
# 24         1   47        1               2        1              1
# ...      ...  ...      ...             ...      ...            ...
# 2981       0   41        1               1        1              1
# 2983       1   30        1               1        2              2
# 2985       1   60        1               2        1              1
# 2998       0   30        1               1        2              2
# 2999       0   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 5                   2        2        2         1                  2
# ...

# %%
k = df[(df['ALCOHOL_CONSUMING'] == 1) & (df['LUNG_CANCER'] == 1)]
k#795 who consumes alcohol and have cancer
# Out:
#       GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 2          1   78        2               2        1              1
# 3          0   60        2               1        1              1
# 16         0   62        1               1        2              2
# 20         1   76        2               2        1              1
# 24         1   47        1               2        1              1
# ...      ...  ...      ...             ...      ...            ...
# 2979       1   33        2               1        1              2
# 2980       0   41        2               1        1              1
# 2986       0   55        2               1        1              2
# 2990       1   57        2               1        2              2
# 2997       1   62        2               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 2                   1        2        1         2                  1
# ...

# %%
k = df[(df['FATIGUE'] == 1) & (df['LUNG_CANCER'] == 1)]
k#who has fatigue has a more chance of having cancer
# Out:
#       GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 3          0   60        2               1        1              1
# 6          1   70        1               1        1              2
# 11         1   60        2               2        1              1
# 16         0   62        1               1        2              2
# 20         1   76        2               2        1              1
# ...      ...  ...      ...             ...      ...            ...
# 2983       1   30        1               1        2              2
# 2985       1   60        1               2        1              1
# 2989       1   74        2               1        2              2
# 2990       1   57        2               1        2              2
# 2999       0   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 3                   2        1        2         1                  1
# ...

# %%
cols = ['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
       'PEER_PRESSURE', 'CHRONIC_DISEASE']
cols
# Out:
# ['GENDER',
#  'AGE',
#  'SMOKING',
#  'YELLOW_FINGERS',
#  'ANXIETY',
#  'PEER_PRESSURE',
#  'CHRONIC_DISEASE']

# %%
sns.swarmplot(x = 'SMOKING',y ='AGE',hue = 'LUNG_CANCER',data = df )
# Out:
# <Axes: xlabel='SMOKING', ylabel='AGE'>

# %%
x = df.drop('LUNG_CANCER',axis =1)

# %%
y = df['LUNG_CANCER']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30,random_state = 1)

# %%
x_train
# Out:
#       GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 2835       0   48        2               1        2              2
# 1793       1   60        1               1        1              1
# 957        1   76        2               1        1              1
# 1385       0   49        1               1        2              2
# 1307       1   50        2               1        1              2
# ...      ...  ...      ...             ...      ...            ...
# 2765       0   78        1               1        1              2
# 905        0   53        1               2        2              2
# 1096       1   74        1               1        1              2
# 235        0   51        1               1        1              2
# 1061       0   60        2               2        2              2
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 2835                1        2        2         2                  1
# ...

# %%
y_train
# Out:
# 2835    0
# 1793    1
# 957     0
# 1385    0
# 1307    1
#        ..
# 2765    0
# 905     1
# 1096    1
# 235     1
# 1061    1
# Name: LUNG_CANCER, Length: 2098, dtype: int32

# %%
from sklearn.linear_model import LinearRegression

# %%
linreg = LinearRegression()

# %%
linreg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
ypred = linreg.predict(x_test)

# %%
ypred
# Out:
# array([0.48105161, 0.50810418, 0.51276479, 0.53973921, 0.49853566,
#        0.41842071, 0.46298627, 0.508883  , 0.52262464, 0.54054079,
#        0.55186481, 0.50424143, 0.52253926, 0.4549594 , 0.43704025,
#        0.5003806 , 0.52823592, 0.51782703, 0.45481779, 0.56130092,
#        0.43586266, 0.5580325 , 0.52890834, 0.5586471 , 0.42383001,
#        0.486227  , 0.56076   , 0.4666646 , 0.49767491, 0.63400478,
#        0.48273756, 0.45223869, 0.46217735, 0.44300513, 0.5693639 ,
#        0.44169018, 0.45070571, 0.49849186, 0.45709708, 0.49873875,
#        0.4219502 , 0.61672336, 0.48897522, 0.47329799, 0.44868914,
#        0.45044157, 0.5380379 , 0.55659828, 0.53931197, 0.49901902,
#        0.54399458, 0.49030829, 0.49564242, 0.47638305, 0.43496135,
#        0.40329829, 0.52575237, 0.522414  , 0.57022944, 0.54011723,
#        0.54305719, 0.51399708, 0.53043957, 0.56375322, 0.53759548,
#        0.46877041, 0.45156674, 0.47443869, 0.4928754 , 0.58173572,
# ...

# %%
linreg.coef_
# Out:
# array([ 0.01287215, -0.00143384,  0.01690261,  0.01266713, -0.00111581,
#        -0.01898802,  0.00223526, -0.0136664 ,  0.01750935, -0.06067524,
#        -0.04274232,  0.04795305, -0.00716678,  0.01517906,  0.0001254 ])

# %%
linreg.intercept_
# Out:
# 0.6243497907853217

# %%
#performance metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
print(mean_squared_error(y_test,ypred))
print(mean_absolute_error(y_test,ypred))
print(np.sqrt(mean_squared_error(y_test,ypred)))
# Out:
# 0.2525793113701717
# 0.49982924011521507
# 0.5025726926228401

# %%
score = r2_score(y_test,ypred)

# %%
score
# Out:
# -0.010636656572146519
